# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280200-max/Calcular-cambio-if-else-/blob/main/El_profe_Act_12_Cambio_Alejandra_Rivera_Valenzuela_0200.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Alejandra Rivera Valenzuela NL = 45 Fecha 26/mar/2026
# ### Calcxulando el cambio usando if else
# ### mirar diagrama de flujo
# ###  Las Variables
# ![texto del enlace](https://raw.githubusercontent.com/a25308051280200-max/Calcular-cambio-if-else-/refs/heads/main/ALE%20Dinero.avif)
# 1. CP --> Costo del producto
# 2. CD --> Cantidad de dinero
# 3. Cambio
#
# ## Formulas
# $Cambio = CD - CP$
#
#
# ![Diagrama de LucidChart](https://raw.githubusercontent.com/a25308051280200-max/Calcular-cambio-if-else-/24ecfa33b773ffe8179f254967a0e788fbde7740/IF%20cambio%202.png)

# %%
# para cuando es verdadero
# calculando cambiuo usando if else
# datos de entrada CD,CP
# mostrar cambio si es falso
# si es verdadero mostrar no alcanza
CD = float(input("Ingrese la cantidad de dinero: "))
CP = float(input("Ingrese el costo del producto: "))
if CP > CD:
    print("No alcanza")
else:
    Cambio = CD - CP
    print("El cambio es: ", Cambio)
    print("Fin del programa ")
    print("Programa realizado por Alejandra Rivera Valenzuela NL = 45")

# %% [markdown]
# # Diagrama
# ![Diagrama de tldraw](https://raw.githubusercontent.com/a25308051280200-max/Calcular-cambio-if-else-/refs/heads/main/ALE%20diagrama.png)
